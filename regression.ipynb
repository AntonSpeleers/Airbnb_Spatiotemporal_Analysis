# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt


columns_to_drop = []
regressiondata = data_copy_clean.drop(columns_to_drop, axis=1)

# Split the data into features (X) and target variable (y)
X = regressiondata.drop('price', axis=1)
y = regressiondata['price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)


# Create a dictionary to store coefficients and their corresponding features
coefficients = {feature: coef for feature, coef in zip(X.columns, model.coef_)}

# Sort the coefficients in descending order based on their absolute values
sorted_coefficients = sorted(coefficients.items(), key=lambda x: abs(x[1]), reverse=True)

# Print sorted coefficients
print("Sorted Coefficients (Feature Importances):")
for feature, coef in sorted_coefficients:
    print(feature, ':', coef)


# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price')
plt.show()
# Out:
# Mean Squared Error: 3676.206498026881
# R^2 Score: 0.6259475082929268
# Coefficients: [ 3.29994254e-01 -1.52452755e+00  1.18296211e+01 -4.55612174e-02
#   1.99308946e-02  1.22652642e+00  9.84519202e+02 -3.92818777e+02
#   1.28528634e+01  5.08477904e+01  2.44204740e+01  4.02943420e+00
#  -8.91634168e-02  2.62319792e-03 -1.06182428e+01 -9.47463354e-02
#   1.22576800e+00 -3.60608557e-01  3.54285845e-02 -1.56423420e-01
#   7.15911058e-01 -6.33417644e+00  1.12359155e+01 -1.94421900e+00
#   1.11885814e+01 -5.63192184e+00 -3.97200665e+00  5.39030598e+00
#  -1.14528236e+01  1.11860290e+01 -4.87730703e-01  6.37902110e-01
#  -2.01714025e+00 -8.79651907e-12 -1.81787897e+00  3.08773342e+01
#  -2.14963472e-04 -9.92874049e+00 -9.16402311e+00 -5.84959347e+00
#   5.60169633e+00 -1.72629213e-01  5.21321210e+00  1.35775890e+01
#   5.68434189e-12 -4.04485741e+00 -9.57811608e-12  1.25473195e+01
#   2.09021298e+00 -4.98808887e+00 -3.15357541e+00 -5.27997523e+00
#   4.99706942e-11 -5.80844955e+00  2.13113557e+01 -1.44950718e-12
#   5.68434189e-14  3.97903932e-13  5.68434189e-14  1.63116377e+00
#  -2.86309213e+00 -3.55271368e-14 -1.26847861e+00  0.00000000e+00
#   6.10019934e+00  5.82373027e+00 -8.75871546e-01 -9.13407923e+00
#  -1.77169706e+00  1.09293673e+00  1.36320112e+01  8.78429336e+00
#  -4.65411060e+00 -4.46833943e+00 -4.77395901e-15  0.00000000e+00
#   4.27064079e+00  3.47125623e+00  3.14031870e+01 -1.42419770e+00
#  -5.19593136e+00 -5.66126656e+00  6.17280173e+00  6.47805724e-02
#   1.34804231e+01 -5.00454309e+00  7.72841040e+00 -2.26548620e+00
#  -1.86607217e+01 -4.43418785e+00 -6.30765303e-02  4.22031895e-01
#  -7.99360578e-15  1.70035115e+00 -2.26375716e+00  3.59112130e+00
#   7.63923906e-01 -1.59410878e+00  9.76996262e-15 -1.55627194e+00
#  -2.69717951e+00  1.45547225e+00  3.55271368e-15  5.32907052e-15
#  -3.55271368e-15  2.66453526e-15 -2.77555756e-15  1.10639021e+00
#   1.81426782e-01 -6.66671449e+00 -3.17725206e+01 -1.24344979e-14
#  -1.24295155e+00 -4.39302067e-02 -2.24332828e+00 -4.66544170e+00
#  -5.84550070e+00  8.36690116e+00  1.26784434e+00  8.88178420e-15
#   1.33226763e-15  1.06603359e+01  1.53611690e+00  1.76440883e+00
#   2.81681123e-01 -3.94609464e-01  1.31311273e+01 -4.24512076e+00
#   0.00000000e+00 -2.41141260e+01  4.52361201e+00  1.48045782e+00
#  -6.76499447e+01  0.00000000e+00 -5.91005280e+01 -6.48467671e+01
#  -3.40442859e+01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00 -3.82376554e+01  0.00000000e+00 -2.90142625e+01
#   0.00000000e+00  0.00000000e+00 -3.33524721e+01 -1.65196578e+01
#   0.00000000e+00  0.00000000e+00 -2.67444926e+01  0.00000000e+00
#  -1.83510027e+01  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   1.33705106e+01  0.00000000e+00 -1.86940607e+01  0.00000000e+00]
# Intercept: -47153.00668269169
# Sorted Coefficients (Feature Importances):
# latitude : 984.5192023829966
# longitude : -392.81877735768086
# neighbourhood_Batignolles-Monceau : -67.64994468320266
# neighbourhood_Buttes-Montmartre : -64.84676709868664
# neighbourhood_Buttes-Chaumont : -59.10052801865753
# bathrooms : 50.84779042829981
# neighbourhood_Ménilmontant : -38.23765540443585
# neighbourhood_Entrepôt : -34.04428593561325
# neighbourhood_Passy : -33.35247207459824
# Kitchen : -31.772520598348862
# Air conditioning : 31.40318703341618
# zero_reviews : 30.877334186230694
# neighbourhood_Opéra : -29.014262479514507
# neighbourhood_Vaugirard : -26.7444926182102
# bedrooms : 24.420474028626927
# Lockbox : -24.114125994738238
# Self check-in : 21.311355745325855
# room_type_Private room : -18.694060691938127
# toys children : -18.660721659837538
# property_type_Apartment : -18.35100268298516
# neighbourhood_Popincourt : -16.51965779754963
# conditioner : 13.632011208592141
# crib : 13.577588960886137
# Dishwasher : 13.480423082761636
# room_type_Entire home/apt : 13.37051056571879
# Fire extinguisher : 13.131127333479412
# accommodates : 12.852863448093403
# Indoor fireplace : 12.547319458795691
# host_is_superhost : 11.829621068818168
# review_scores_value : -11.452823553296295
# review_scores_rating : 11.235915510797625
# review_scores_cleanliness : 11.188581420763185
# instant_bookable : 11.186028957894075
# Free dryer – In unit : 10.6603358898129
# has_availability : -10.618242841151535
# Cleaning available during stay : -9.928740485064505
# Laundromat nearby : -9.16402311059298
# Mini fridge : -9.134079229013318
# Private patio or balcony : 8.78429335669667
# broadcast : 8.36690115773444
# Bathtub : 7.728410404675283
# refrigerator : -6.6667144853108935
# number_of_reviews_l30d : -6.334176440459746
# tv : 6.1728017260089985
# Dining table : 6.100199341955772
# Smoking allowed : -5.849593468887683
# Heating : -5.84550069720729
# wifi : 5.823730271952381
# Essentials : -5.808449549542888
# Microwave : -5.661266563551758
# review_scores_checkin : -5.631921841684554
# view : 5.601696333051825
# review_scores_location : 5.390305981213309
# Hot water : -5.2799752299563565
# Shower gel : 5.213212101544406
# Drying rack for clothing : -5.195931363924379
# backyard : -5.004543090684744
# Extra pillows and blankets : -4.988088871680619
# Long term stays allowed : -4.665441699661271
# Room-darkening shades : -4.654110603674625
# Freezer : 4.523612005763011
# clothing storage : -4.4683394310720965
# Cooking basics : -4.434187854210307
# Patio or balcony : 4.270640793227134
# Wine glasses : -4.245120755994636
# Single level home : -4.044857409477171
# beds : 4.02943419920585
# review_scores_communication : -3.972006653188375
# Carbon monoxide alarm : 3.5911212979452847
# Dryer : 3.4712562263514197
# soap : -3.1535754082270384
# Portable fans : -2.8630921334802144
# parking : -2.6971795107911696
# Dedicated workspace : -2.2654862035188934
# Iron : -2.263757164012726
# Pets allowed : -2.243328275935519
# Host greets you : 2.0902129756159895
# calculated_host_listings_count_private_rooms : -2.0171402503032754
# review_scores_accuracy : -1.944218995883678
# reviews_per_month : -1.8178789735638432
# Hangers : -1.771697059694143
# oven : 1.7644088308703676
# Free washer – In unit : 1.7003511481129783
# Toaster : 1.631163769681395
# stove : -1.594108781133667
# Bed linens : -1.5562719399791982
# Baking sheet : 1.5361168992158776
# host_response_rate : -1.5245275505490388
# total_amenities : 1.480457817907734
# shampoo : 1.4554722471175818
# Ethernet connection : -1.4241977024626526
# Hot water kettle : -1.2684786110944826
# Blender : 1.2678443434272686
# Smoke alarm : -1.2429515521901742
# host_identity_verified : 1.2265264190802427
# availability_60 : 1.2257679954265157
# Central heating : 1.1063902100052978
# Hair dryer : 1.0929367250868152
# Washer : -0.8758715459921147
# Dishes and silverware : 0.7639239064808745
# number_of_reviews_ltm : 0.7159110575394578
# calculated_host_listings_count_entire_homes : 0.6379021101084561
# calculated_host_listings_count : -0.48773070287100495
# Books and reading material : 0.42203189536557595
# Elevator : -0.39460946357866367
# availability_90 : -0.36060855693826
# host_response_time : 0.32999425416361483
# Luggage dropoff allowed : 0.28168112324188654
# First aid kit : 0.18142678165760961
# Breakfast : -0.17262921262975484
# number_of_reviews : -0.1564234204067816
# availability_30 : -0.0947463353779412
# minimum_nights : -0.08916341679304196
# Private entrance : 0.0647805723559034
# Cleaning products : -0.06307653033233507
# host_listings_count : -0.045561217353250916
# coffee : -0.04393020673033732
# availability_365 : 0.03542858453431563
# host_total_listings_count : 0.019930894586702497
# maximum_nights : 0.0026231979183570786
# days_since_host : -0.00021496347221727774
# Building staff : 4.9970694249168446e-11
# gym : -9.57811607804615e-12
# calculated_host_listings_count_shared_rooms : -8.79651906871004e-12
# game console : 5.6843418860808015e-12
# Safe : -1.4495071809506044e-12
# Sound system : 3.979039320256561e-13
# Outdoor furniture : 5.684341886080802e-14
# Security cameras on property : 5.684341886080802e-14
# sound system : -3.552713678800501e-14
# exercise equipment : -1.2434497875801753e-14
# Radiant heating : 9.769962616701378e-15
# High chair : 8.881784197001252e-15
# pool : -7.993605777301127e-15
# Portable heater : 5.329070518200751e-15
# bbq : -4.773959005888173e-15
# Outdoor dining area : 3.552713678800501e-15
# Rice maker : -3.552713678800501e-15
# Bread maker : -2.7755575615628914e-15
# Board games : 2.6645352591003757e-15
# Babysitter recommendations : 1.3322676295501878e-15
# Lock on bedroom door : 0.0
# hot tub : 0.0
# Piano : 0.0
# neighbourhood_Bourse : 0.0
# neighbourhood_Gobelins : 0.0
# neighbourhood_Hôtel-de-Ville : 0.0
# neighbourhood_Louvre : 0.0
# neighbourhood_Luxembourg : 0.0
# neighbourhood_Observatoire : 0.0
# neighbourhood_Palais-Bourbon : 0.0
# neighbourhood_Panthéon : 0.0
# neighbourhood_Reuilly : 0.0
# neighbourhood_Temple : 0.0
# neighbourhood_Élysée : 0.0
# property_type_Hotel : 0.0
# property_type_House : 0.0
# property_type_Other : 0.0
# room_type_Hotel room : 0.0
# room_type_Shared room : 0.0

# %%
columns_to_drop = ['host_response_time', 'calculated_host_listings_count_shared_rooms', 'zero_reviews', 'hot tub', 
                   'Security cameras on property', 'Central heating', 'Building staff', 'Blender', 'oven', 
                   'sound system', 'Hangers', 'Outdoor dining area', 'Bread maker', 'pool', 'Outdoor furniture',
                   'High chair', 'Board games', 'game console', 'gym', 'Lock on bedroom door', 'Radiant heating', 
                   'Safe', 'Portable heater', 'Smoking allowed', 'Sound system', 'Rice maker', 'bbq', 'Dishwasher',
                   'exercise equipment', 'Piano', 'Babysitter recommendations', 'neighbourhood_Bourse', 'neighbourhood_Gobelins', 
                   'neighbourhood_Hôtel-de-Ville', 'neighbourhood_Louvre', 'neighbourhood_Luxembourg',
                   'neighbourhood_Observatoire',
                   'neighbourhood_Palais-Bourbon', 'neighbourhood_Panthéon', 'neighbourhood_Reuilly', 'neighbourhood_Temple',
                   'neighbourhood_Élysée', 'property_type_Hotel',
                   'property_type_House', 'property_type_Other', 'room_type_Hotel room', 'room_type_Shared room']

regressiondata = data_copy_clean.drop(columns_to_drop, axis=1)

# Split the data into features (X) and target variable (y)
X = regressiondata.drop('price', axis=1)
y = regressiondata['price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)


# Create a dictionary to store coefficients and their corresponding features
coefficients = {feature: coef for feature, coef in zip(X.columns, model.coef_)}

# Sort the coefficients in descending order based on their absolute values
sorted_coefficients = sorted(coefficients.items(), key=lambda x: abs(x[1]), reverse=True)

# Print sorted coefficients
print("Sorted Coefficients (Feature Importances):")
for feature, coef in sorted_coefficients:
    print(feature, ':', coef)


# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price')
plt.show()
# Out:
# Mean Squared Error: 3712.9946817675113
# R^2 Score: 0.6222043258027847
# Coefficients: [-1.87513626e+00  1.26642488e+01 -5.99339852e-02  4.11570200e-02
#   1.70232744e+00  9.88682842e+02 -4.03022298e+02  1.28697775e+01
#   5.12565695e+01  2.55730287e+01  3.89474761e+00 -9.12071604e-02
#   2.42812595e-03 -1.12078579e+01 -1.09477581e-01  1.23232497e+00
#  -3.69482859e-01  3.56499556e-02 -1.58028937e-01  7.16848953e-01
#  -6.35581433e+00  1.05594357e+01 -2.13397915e+00  1.14466693e+01
#  -7.42297453e+00 -5.42126241e+00  1.69831174e+00 -9.89225984e+00
#   1.08237030e+01 -4.58399538e-01  6.00018992e-01 -2.14577310e+00
#  -2.38975526e+00 -3.53650479e-04 -1.05654052e+01 -1.04018496e+01
#   4.79130624e+00 -1.37679203e+00  3.88760751e+00  1.35863952e+01
#  -4.47526179e+00  1.20966076e+01  1.29932694e+00 -6.27979526e+00
#  -4.01012494e+00 -5.79498430e+00 -7.37549992e+00  1.97487630e+01
#   2.31640280e+00 -3.53337085e+00 -1.85759764e+00  6.15896328e+00
#   5.25540513e+00 -7.66786531e-01 -1.14555750e+01  5.12265500e-01
#   1.34895683e+01  8.58695694e+00 -5.09437752e+00 -6.38952164e+00
#   4.87589707e+00  3.46405154e+00  3.08447748e+01 -2.17364419e+00
#  -5.98576742e+00 -5.11601901e+00  5.68679704e+00 -9.84757460e-01
#  -5.75720073e+00  7.94514266e+00 -3.16162329e+00 -1.91048070e+01
#  -4.34122778e+00 -1.69111203e+00  2.72543580e-01  1.76912904e+00
#  -3.38908847e+00  3.09753676e+00 -9.65589256e-01 -9.96658192e-01
#  -1.28441227e+00 -3.58326220e+00  5.13339244e-01 -4.85319686e-01
#  -5.61101890e+00 -3.25539415e+01 -1.88119833e+00 -4.26797052e-02
#  -4.94709841e+00 -6.13676731e+00 -7.06181696e+00  8.11727081e+00
#   1.17453837e+01  1.36472454e+00 -5.61793252e-01 -8.87279149e-01
#   1.24372853e+01 -5.49073644e+00 -2.35953751e+01  6.36369070e+00
#   2.29157693e+00 -6.81797819e+01 -5.96976735e+01 -6.60312985e+01
#  -3.43940519e+01 -3.89694925e+01 -2.91372123e+01 -3.40736233e+01
#  -1.65937606e+01 -2.72668182e+01 -1.86398950e+01  1.45684051e+01
#  -1.84969916e+01]
# Intercept: -47305.55584376206
# Sorted Coefficients (Feature Importances):
# latitude : 988.6828418434056
# longitude : -403.02229783079156
# neighbourhood_Batignolles-Monceau : -68.17978186548645
# neighbourhood_Buttes-Montmartre : -66.03129848183322
# neighbourhood_Buttes-Chaumont : -59.69767345667737
# bathrooms : 51.25656950123272
# neighbourhood_Ménilmontant : -38.96949253123079
# neighbourhood_Entrepôt : -34.39405190787191
# neighbourhood_Passy : -34.07362325878725
# Kitchen : -32.55394148978286
# Air conditioning : 30.844774760592763
# neighbourhood_Opéra : -29.13721231071001
# neighbourhood_Vaugirard : -27.266818211040203
# bedrooms : 25.573028729604417
# Lockbox : -23.595375140931033
# Self check-in : 19.74876299620092
# toys children : -19.10480696813578
# property_type_Apartment : -18.63989503410265
# room_type_Private room : -18.496991579193406
# neighbourhood_Popincourt : -16.593760589671284
# room_type_Entire home/apt : 14.568405122647889
# crib : 13.58639517248842
# conditioner : 13.48956832963974
# accommodates : 12.869777479515886
# host_is_superhost : 12.664248798746163
# Fire extinguisher : 12.43728530055555
# Indoor fireplace : 12.09660761958737
# Free dryer – In unit : 11.745383719098715
# Mini fridge : -11.455574980830367
# review_scores_cleanliness : 11.446669298602558
# has_availability : -11.20785794682053
# instant_bookable : 10.823703005184404
# Cleaning available during stay : -10.565405223430988
# review_scores_rating : 10.559435702887146
# Laundromat nearby : -10.401849641526725
# review_scores_value : -9.892259841411335
# Private patio or balcony : 8.5869569435748
# broadcast : 8.117270805158714
# Bathtub : 7.945142658236264
# review_scores_checkin : -7.422974532146613
# Essentials : -7.375499917978515
# Heating : -7.061816961926061
# clothing storage : -6.389521642890092
# Freezer : 6.363690703449695
# number_of_reviews_l30d : -6.355814326089337
# Extra pillows and blankets : -6.279795264048489
# Dining table : 6.1589632838350905
# Long term stays allowed : -6.13676730643942
# Drying rack for clothing : -5.985767417070637
# Hot water : -5.794984304584029
# backyard : -5.757200729525485
# tv : 5.686797037521289
# refrigerator : -5.611018898520719
# Wine glasses : -5.490736440837793
# review_scores_communication : -5.421262410667971
# wifi : 5.255405131446518
# Microwave : -5.116019009597049
# Room-darkening shades : -5.094377520510585
# Pets allowed : -4.947098405143067
# Patio or balcony : 4.875897070001522
# view : 4.79130624172109
# Single level home : -4.4752617941963
# Cooking basics : -4.341227778774591
# soap : -4.010124936026846
# beds : 3.8947476096439733
# Shower gel : 3.887607505978494
# parking : -3.5832622032975334
# Portable fans : -3.533370845599954
# Dryer : 3.464051543164062
# Iron : -3.3890884651256497
# Dedicated workspace : -3.1616232850335475
# Carbon monoxide alarm : 3.0975367581835633
# reviews_per_month : -2.389755255034082
# Toaster : 2.3164027961473073
# total_amenities : 2.2915769300087447
# Ethernet connection : -2.1736441856143593
# calculated_host_listings_count_private_rooms : -2.1457731022261086
# review_scores_accuracy : -2.1339791486240207
# Smoke alarm : -1.8811983332174795
# host_response_rate : -1.8751362596645818
# Hot water kettle : -1.857597635408994
# Free washer – In unit : 1.7691290434071734
# host_identity_verified : 1.7023274425271564
# review_scores_location : 1.6983117374920838
# Cleaning products : -1.6911120253964942
# Breakfast : -1.376792029515265
# Baking sheet : 1.3647245440532974
# Host greets you : 1.2993269363747961
# Bed linens : -1.2844122658224864
# availability_60 : 1.2323249716100761
# stove : -0.9966581916414889
# Private entrance : -0.984757460159245
# Dishes and silverware : -0.9655892558021346
# Elevator : -0.8872791485558342
# Washer : -0.7667865310033122
# number_of_reviews_ltm : 0.7168489525317909
# calculated_host_listings_count_entire_homes : 0.600018992377656
# Luggage dropoff allowed : -0.5617932523694238
# shampoo : 0.5133392437464224
# Hair dryer : 0.51226549967387
# First aid kit : -0.4853196856712241
# calculated_host_listings_count : -0.45839953822746793
# availability_90 : -0.3694828593655757
# Books and reading material : 0.2725435798254434
# number_of_reviews : -0.15802893657587447
# availability_30 : -0.10947758148165487
# minimum_nights : -0.09120716038569299
# host_listings_count : -0.05993398515445532
# coffee : -0.04267970524093556
# host_total_listings_count : 0.04115701998709281
# availability_365 : 0.03564995558701867
# maximum_nights : 0.0024281259468068583
# days_since_host : -0.0003536504791270545

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt


from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)  # You can adjust the regularization strength (alpha) as needed

# Fit the model on the training data
lasso.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = lasso.predict(X_test)

# Calculate performance measures
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * (mae / y_test.mean())

print("Mean Squared Error:", mse)
print("R-squared:", r2)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs. Predicted Prices')
plt.show()

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)


# Create a dictionary to store coefficients and their corresponding features
coefficients = {feature: coef for feature, coef in zip(X.columns, model.coef_)}

# Sort the coefficients in descending order based on their absolute values
sorted_coefficients = sorted(coefficients.items(), key=lambda x: abs(x[1]), reverse=True)

# Print sorted coefficients
print("Sorted Coefficients (Feature Importances):")
for feature, coef in sorted_coefficients:
    print(feature, ':', coef)
# Out:
# Requirement already satisfied: pandas in c:\program files\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: scikit-learn in c:\program files\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: xgboost in c:\program files\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\program files\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\program files\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\program files\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\program files\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\program files\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\program files\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\program files\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\program files\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Mean Squared Error: 3869.7433191485898
# R-squared: 0.6062552167373527
# Mean Absolute Error: 44.85664215373114
# Mean Absolute Percentage Error: 31.208629129672417
# Coefficients: [-1.87513626e+00  1.26642488e+01 -5.99339852e-02  4.11570200e-02
#   1.70232744e+00  9.88682842e+02 -4.03022298e+02  1.28697775e+01
#   5.12565695e+01  2.55730287e+01  3.89474761e+00 -9.12071604e-02
#   2.42812595e-03 -1.12078579e+01 -1.09477581e-01  1.23232497e+00
#  -3.69482859e-01  3.56499556e-02 -1.58028937e-01  7.16848953e-01
#  -6.35581433e+00  1.05594357e+01 -2.13397915e+00  1.14466693e+01
#  -7.42297453e+00 -5.42126241e+00  1.69831174e+00 -9.89225984e+00
#   1.08237030e+01 -4.58399538e-01  6.00018992e-01 -2.14577310e+00
#  -2.38975526e+00 -3.53650479e-04 -1.05654052e+01 -1.04018496e+01
#   4.79130624e+00 -1.37679203e+00  3.88760751e+00  1.35863952e+01
#  -4.47526179e+00  1.20966076e+01  1.29932694e+00 -6.27979526e+00
#  -4.01012494e+00 -5.79498430e+00 -7.37549992e+00  1.97487630e+01
#   2.31640280e+00 -3.53337085e+00 -1.85759764e+00  6.15896328e+00
#   5.25540513e+00 -7.66786531e-01 -1.14555750e+01  5.12265500e-01
#   1.34895683e+01  8.58695694e+00 -5.09437752e+00 -6.38952164e+00
#   4.87589707e+00  3.46405154e+00  3.08447748e+01 -2.17364419e+00
#  -5.98576742e+00 -5.11601901e+00  5.68679704e+00 -9.84757460e-01
#  -5.75720073e+00  7.94514266e+00 -3.16162329e+00 -1.91048070e+01
#  -4.34122778e+00 -1.69111203e+00  2.72543580e-01  1.76912904e+00
#  -3.38908847e+00  3.09753676e+00 -9.65589256e-01 -9.96658192e-01
#  -1.28441227e+00 -3.58326220e+00  5.13339244e-01 -4.85319686e-01
#  -5.61101890e+00 -3.25539415e+01 -1.88119833e+00 -4.26797052e-02
#  -4.94709841e+00 -6.13676731e+00 -7.06181696e+00  8.11727081e+00
#   1.17453837e+01  1.36472454e+00 -5.61793252e-01 -8.87279149e-01
#   1.24372853e+01 -5.49073644e+00 -2.35953751e+01  6.36369070e+00
#   2.29157693e+00 -6.81797819e+01 -5.96976735e+01 -6.60312985e+01
#  -3.43940519e+01 -3.89694925e+01 -2.91372123e+01 -3.40736233e+01
#  -1.65937606e+01 -2.72668182e+01 -1.86398950e+01  1.45684051e+01
#  -1.84969916e+01]
# Intercept: -47305.55584376206
# Sorted Coefficients (Feature Importances):
# latitude : 988.6828418434056
# longitude : -403.02229783079156
# neighbourhood_Batignolles-Monceau : -68.17978186548645
# neighbourhood_Buttes-Montmartre : -66.03129848183322
# neighbourhood_Buttes-Chaumont : -59.69767345667737
# bathrooms : 51.25656950123272
# neighbourhood_Ménilmontant : -38.96949253123079
# neighbourhood_Entrepôt : -34.39405190787191
# neighbourhood_Passy : -34.07362325878725
# Kitchen : -32.55394148978286
# Air conditioning : 30.844774760592763
# neighbourhood_Opéra : -29.13721231071001
# neighbourhood_Vaugirard : -27.266818211040203
# bedrooms : 25.573028729604417
# Lockbox : -23.595375140931033
# Self check-in : 19.74876299620092
# toys children : -19.10480696813578
# property_type_Apartment : -18.63989503410265
# room_type_Private room : -18.496991579193406
# neighbourhood_Popincourt : -16.593760589671284
# room_type_Entire home/apt : 14.568405122647889
# crib : 13.58639517248842
# conditioner : 13.48956832963974
# accommodates : 12.869777479515886
# host_is_superhost : 12.664248798746163
# Fire extinguisher : 12.43728530055555
# Indoor fireplace : 12.09660761958737
# Free dryer – In unit : 11.745383719098715
# Mini fridge : -11.455574980830367
# review_scores_cleanliness : 11.446669298602558
# has_availability : -11.20785794682053
# instant_bookable : 10.823703005184404
# Cleaning available during stay : -10.565405223430988
# review_scores_rating : 10.559435702887146
# Laundromat nearby : -10.401849641526725
# review_scores_value : -9.892259841411335
# Private patio or balcony : 8.5869569435748
# broadcast : 8.117270805158714
# Bathtub : 7.945142658236264
# review_scores_checkin : -7.422974532146613
# Essentials : -7.375499917978515
# Heating : -7.061816961926061
# clothing storage : -6.389521642890092
# Freezer : 6.363690703449695
# number_of_reviews_l30d : -6.355814326089337
# Extra pillows and blankets : -6.279795264048489
# Dining table : 6.1589632838350905
# Long term stays allowed : -6.13676730643942
# Drying rack for clothing : -5.985767417070637
# Hot water : -5.794984304584029
# backyard : -5.757200729525485
# tv : 5.686797037521289
# refrigerator : -5.611018898520719
# Wine glasses : -5.490736440837793
# review_scores_communication : -5.421262410667971
# wifi : 5.255405131446518
# Microwave : -5.116019009597049
# Room-darkening shades : -5.094377520510585
# Pets allowed : -4.947098405143067
# Patio or balcony : 4.875897070001522
# view : 4.79130624172109
# Single level home : -4.4752617941963
# Cooking basics : -4.341227778774591
# soap : -4.010124936026846
# beds : 3.8947476096439733
# Shower gel : 3.887607505978494
# parking : -3.5832622032975334
# Portable fans : -3.533370845599954
# Dryer : 3.464051543164062
# Iron : -3.3890884651256497
# Dedicated workspace : -3.1616232850335475
# Carbon monoxide alarm : 3.0975367581835633
# reviews_per_month : -2.389755255034082
# Toaster : 2.3164027961473073
# total_amenities : 2.2915769300087447
# Ethernet connection : -2.1736441856143593
# calculated_host_listings_count_private_rooms : -2.1457731022261086
# review_scores_accuracy : -2.1339791486240207
# Smoke alarm : -1.8811983332174795
# host_response_rate : -1.8751362596645818
# Hot water kettle : -1.857597635408994
# Free washer – In unit : 1.7691290434071734
# host_identity_verified : 1.7023274425271564
# review_scores_location : 1.6983117374920838
# Cleaning products : -1.6911120253964942
# Breakfast : -1.376792029515265
# Baking sheet : 1.3647245440532974
# Host greets you : 1.2993269363747961
# Bed linens : -1.2844122658224864
# availability_60 : 1.2323249716100761
# stove : -0.9966581916414889
# Private entrance : -0.984757460159245
# Dishes and silverware : -0.9655892558021346
# Elevator : -0.8872791485558342
# Washer : -0.7667865310033122
# number_of_reviews_ltm : 0.7168489525317909
# calculated_host_listings_count_entire_homes : 0.600018992377656
# Luggage dropoff allowed : -0.5617932523694238
# shampoo : 0.5133392437464224
# Hair dryer : 0.51226549967387
# First aid kit : -0.4853196856712241
# calculated_host_listings_count : -0.45839953822746793
# availability_90 : -0.3694828593655757
# Books and reading material : 0.2725435798254434
# number_of_reviews : -0.15802893657587447
# availability_30 : -0.10947758148165487
# minimum_nights : -0.09120716038569299
# host_listings_count : -0.05993398515445532
# coffee : -0.04267970524093556
# host_total_listings_count : 0.04115701998709281
# availability_365 : 0.03564995558701867
# maximum_nights : 0.0024281259468068583
# days_since_host : -0.0003536504791270545

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.1)  # You can adjust the regularization strength (alpha) as needed

# Fit the model on the training data
ridge.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = ridge.predict(X_test)

# Calculate performance measures
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = 100 * (mae / y_test.mean())

print("Mean Squared Error:", mse)
print("R-squared:", r2)
print("Mean Absolute Error:", mae)
print("Mean Absolute Percentage Error:", mape)

# Plot actual vs. predicted prices
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs. Predicted Prices')
plt.show()

# Get the coefficients and intercept
coefficients = model.coef_
intercept = model.intercept_
print("Coefficients:", coefficients)
print("Intercept:", intercept)


# Create a dictionary to store coefficients and their corresponding features
coefficients = {feature: coef for feature, coef in zip(X.columns, model.coef_)}

# Sort the coefficients in descending order based on their absolute values
sorted_coefficients = sorted(coefficients.items(), key=lambda x: abs(x[1]), reverse=True)

# Print sorted coefficients
print("Sorted Coefficients (Feature Importances):")
for feature, coef in sorted_coefficients:
    print(feature, ':', coef)
# Out:
# Mean Squared Error: 3713.6729168147804
# R-squared: 0.6221353156670565
# Mean Absolute Error: 43.92614678104535
# Mean Absolute Percentage Error: 30.561244849469183
# Coefficients: [-1.87513626e+00  1.26642488e+01 -5.99339852e-02  4.11570200e-02
#   1.70232744e+00  9.88682842e+02 -4.03022298e+02  1.28697775e+01
#   5.12565695e+01  2.55730287e+01  3.89474761e+00 -9.12071604e-02
#   2.42812595e-03 -1.12078579e+01 -1.09477581e-01  1.23232497e+00
#  -3.69482859e-01  3.56499556e-02 -1.58028937e-01  7.16848953e-01
#  -6.35581433e+00  1.05594357e+01 -2.13397915e+00  1.14466693e+01
#  -7.42297453e+00 -5.42126241e+00  1.69831174e+00 -9.89225984e+00
#   1.08237030e+01 -4.58399538e-01  6.00018992e-01 -2.14577310e+00
#  -2.38975526e+00 -3.53650479e-04 -1.05654052e+01 -1.04018496e+01
#   4.79130624e+00 -1.37679203e+00  3.88760751e+00  1.35863952e+01
#  -4.47526179e+00  1.20966076e+01  1.29932694e+00 -6.27979526e+00
#  -4.01012494e+00 -5.79498430e+00 -7.37549992e+00  1.97487630e+01
#   2.31640280e+00 -3.53337085e+00 -1.85759764e+00  6.15896328e+00
#   5.25540513e+00 -7.66786531e-01 -1.14555750e+01  5.12265500e-01
#   1.34895683e+01  8.58695694e+00 -5.09437752e+00 -6.38952164e+00
#   4.87589707e+00  3.46405154e+00  3.08447748e+01 -2.17364419e+00
#  -5.98576742e+00 -5.11601901e+00  5.68679704e+00 -9.84757460e-01
#  -5.75720073e+00  7.94514266e+00 -3.16162329e+00 -1.91048070e+01
#  -4.34122778e+00 -1.69111203e+00  2.72543580e-01  1.76912904e+00
#  -3.38908847e+00  3.09753676e+00 -9.65589256e-01 -9.96658192e-01
#  -1.28441227e+00 -3.58326220e+00  5.13339244e-01 -4.85319686e-01
#  -5.61101890e+00 -3.25539415e+01 -1.88119833e+00 -4.26797052e-02
#  -4.94709841e+00 -6.13676731e+00 -7.06181696e+00  8.11727081e+00
#   1.17453837e+01  1.36472454e+00 -5.61793252e-01 -8.87279149e-01
#   1.24372853e+01 -5.49073644e+00 -2.35953751e+01  6.36369070e+00
#   2.29157693e+00 -6.81797819e+01 -5.96976735e+01 -6.60312985e+01
#  -3.43940519e+01 -3.89694925e+01 -2.91372123e+01 -3.40736233e+01
#  -1.65937606e+01 -2.72668182e+01 -1.86398950e+01  1.45684051e+01
#  -1.84969916e+01]
# Intercept: -47305.55584376206
# Sorted Coefficients (Feature Importances):
# latitude : 988.6828418434056
# longitude : -403.02229783079156
# neighbourhood_Batignolles-Monceau : -68.17978186548645
# neighbourhood_Buttes-Montmartre : -66.03129848183322
# neighbourhood_Buttes-Chaumont : -59.69767345667737
# bathrooms : 51.25656950123272
# neighbourhood_Ménilmontant : -38.96949253123079
# neighbourhood_Entrepôt : -34.39405190787191
# neighbourhood_Passy : -34.07362325878725
# Kitchen : -32.55394148978286
# Air conditioning : 30.844774760592763
# neighbourhood_Opéra : -29.13721231071001
# neighbourhood_Vaugirard : -27.266818211040203
# bedrooms : 25.573028729604417
# Lockbox : -23.595375140931033
# Self check-in : 19.74876299620092
# toys children : -19.10480696813578
# property_type_Apartment : -18.63989503410265
# room_type_Private room : -18.496991579193406
# neighbourhood_Popincourt : -16.593760589671284
# room_type_Entire home/apt : 14.568405122647889
# crib : 13.58639517248842
# conditioner : 13.48956832963974
# accommodates : 12.869777479515886
# host_is_superhost : 12.664248798746163
# Fire extinguisher : 12.43728530055555
# Indoor fireplace : 12.09660761958737
# Free dryer – In unit : 11.745383719098715
# Mini fridge : -11.455574980830367
# review_scores_cleanliness : 11.446669298602558
# has_availability : -11.20785794682053
# instant_bookable : 10.823703005184404
# Cleaning available during stay : -10.565405223430988
# review_scores_rating : 10.559435702887146
# Laundromat nearby : -10.401849641526725
# review_scores_value : -9.892259841411335
# Private patio or balcony : 8.5869569435748
# broadcast : 8.117270805158714
# Bathtub : 7.945142658236264
# review_scores_checkin : -7.422974532146613
# Essentials : -7.375499917978515
# Heating : -7.061816961926061
# clothing storage : -6.389521642890092
# Freezer : 6.363690703449695
# number_of_reviews_l30d : -6.355814326089337
# Extra pillows and blankets : -6.279795264048489
# Dining table : 6.1589632838350905
# Long term stays allowed : -6.13676730643942
# Drying rack for clothing : -5.985767417070637
# Hot water : -5.794984304584029
# backyard : -5.757200729525485
# tv : 5.686797037521289
# refrigerator : -5.611018898520719
# Wine glasses : -5.490736440837793
# review_scores_communication : -5.421262410667971
# wifi : 5.255405131446518
# Microwave : -5.116019009597049
# Room-darkening shades : -5.094377520510585
# Pets allowed : -4.947098405143067
# Patio or balcony : 4.875897070001522
# view : 4.79130624172109
# Single level home : -4.4752617941963
# Cooking basics : -4.341227778774591
# soap : -4.010124936026846
# beds : 3.8947476096439733
# Shower gel : 3.887607505978494
# parking : -3.5832622032975334
# Portable fans : -3.533370845599954
# Dryer : 3.464051543164062
# Iron : -3.3890884651256497
# Dedicated workspace : -3.1616232850335475
# Carbon monoxide alarm : 3.0975367581835633
# reviews_per_month : -2.389755255034082
# Toaster : 2.3164027961473073
# total_amenities : 2.2915769300087447
# Ethernet connection : -2.1736441856143593
# calculated_host_listings_count_private_rooms : -2.1457731022261086
# review_scores_accuracy : -2.1339791486240207
# Smoke alarm : -1.8811983332174795
# host_response_rate : -1.8751362596645818
# Hot water kettle : -1.857597635408994
# Free washer – In unit : 1.7691290434071734
# host_identity_verified : 1.7023274425271564
# review_scores_location : 1.6983117374920838
# Cleaning products : -1.6911120253964942
# Breakfast : -1.376792029515265
# Baking sheet : 1.3647245440532974
# Host greets you : 1.2993269363747961
# Bed linens : -1.2844122658224864
# availability_60 : 1.2323249716100761
# stove : -0.9966581916414889
# Private entrance : -0.984757460159245
# Dishes and silverware : -0.9655892558021346
# Elevator : -0.8872791485558342
# Washer : -0.7667865310033122
# number_of_reviews_ltm : 0.7168489525317909
# calculated_host_listings_count_entire_homes : 0.600018992377656
# Luggage dropoff allowed : -0.5617932523694238
# shampoo : 0.5133392437464224
# Hair dryer : 0.51226549967387
# First aid kit : -0.4853196856712241
# calculated_host_listings_count : -0.45839953822746793
# availability_90 : -0.3694828593655757
# Books and reading material : 0.2725435798254434
# number_of_reviews : -0.15802893657587447
# availability_30 : -0.10947758148165487
# minimum_nights : -0.09120716038569299
# host_listings_count : -0.05993398515445532
# coffee : -0.04267970524093556
# host_total_listings_count : 0.04115701998709281
# availability_365 : 0.03564995558701867
# maximum_nights : 0.0024281259468068583
# days_since_host : -0.0003536504791270545
